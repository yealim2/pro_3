# %% [markdown]
# # <div style="text-align:center">2021년 봄학기 프로그래밍3 - 12주차 <br/><시계열 분석></div>
#
# <div style="text-align: right"> <b>강남대학교 인공지능융합공학부 데이터사이언스전공 곽찬희</b></div>
# <div style="text-align: right"> <b>chk at kangnam dot ac dot kr</b></div>
#
# ---
# ### 공지사항
# - 향후 수업 진행 일정
#     - 10주차(5/10): 데이터 재구성 및 pandas 객체 병합
#     - **오늘!11주차: 시계열 분석**
#     - 12주차: 인덱스 정렬 & 시각화 / 중간 보고 제출(github 링크)
#     - 13주차: 디버깅 및 테스트 / 과제 진행
#     - 14주차: 발표 - github 를 이용한 10분 발표 / (동영상 제출 마감)
#     - 15주차: 기말고사 및 학기 종료 (기말고사 형태는 추후 공지)
# - 발표순서는 확정해서 알려드리겠습니다 (아마 학번순)
# ---
#
# # 0. 개요
#
# 오늘은 다음의 내용에 대해 배우겠습니다.
#
# 1. 시계열 데이터가 무엇인지?
#
# 2. Datetime 객체를 이용해 시간을 표현하고, 필터링하는 방법
#
# 3. 시계열 시각화

# %% [markdown]
# ---
#
# # 1. 파이썬과 pandas 날짜 도구들
#
# 기본적인 사항들을 먼저 짚어봅시다.
#
# - 파이썬에서 시간과 날짜를 다루는 기본 형식은 datetime 모듈의 date, time, datetime 입니다.
#
# - date는 연/월/일, time은 시/분/초/마이크로초, datetime = date + time 으로 구성됩니다.
#
# - pandas 에서는 Timestamp 라고 하는 data type 이 있으며, 이는 numpy의 datetime64 에서 파생되었습니다.
#
# - pandas 와 파이썬에서는 날짜 차이를 계산하기 위한 timedelta 객체가 있습니다.

# %%
import pandas as pd
import numpy as np
import datetime

date = datetime.date(year=2013, month=6, day=7)
time = datetime.time(hour=12, minute=30, second=19, microsecond=418237)

dt = datetime.datetime(year=2013, month=6, day=7, hour=12, minute=30, second=19, microsecond=758234)

# %%
print(f'this is date:{date}\nthis is time:{time}\nthis is dt:{dt}')
# Out:
# this is date:2013-06-07
# this is time:12:30:19.418237
# this is dt:2013-06-07 12:30:19.758234

# %%
#이번엔 timedelta 입니다.
td = datetime.timedelta(weeks=2, days=5, hours=10, minutes=20, seconds=6.73, 
                        milliseconds=99, microseconds=8)
td
# Out:
# datetime.timedelta(days=19, seconds=37206, microseconds=829008)

# %%
#td 를 만드는 이유는 시간 계산을 하기 위함입니다.

print(f'td + date = {td + date}')
print(f'td + dt = {td + dt}')
# Out:
# td + date = 2013-06-26
# td + dt = 2013-06-26 22:50:26.587242

# %%
#td + time 은 애러가 납니다.
td + time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-8f030636c492> in <module>
#       1 #td + time 은 애러가 납니다.
# ----> 2 td + time
#
# TypeError: unsupported operand type(s) for +: 'datetime.timedelta' and 'datetime.time'

# %%
# 이제는 pandas 로 넘어와서, Timestamp 를 사용해봅시다.
# python 의 datetime 과 유사하지만, 조금 더 정밀하고 유연합니다.

pd.Timestamp(year=2012, month=12, day=21, hour=5, 
             minute=10, second=8, microsecond=99)
# Out:
# Timestamp('2012-12-21 05:10:08.000099')

# %%
pd.Timestamp('2016-1-10')
# Out:
# Timestamp('2016-01-10 00:00:00')

# %%
#형식이 섞여 있어도 이렇게!
pd.Timestamp('2014-5/10')
# Out:
# Timestamp('2014-05-10 00:00:00')

# %%
pd.Timestamp('Jan 3, 2019 20:45.56')
# Out:
# Timestamp('2019-01-03 20:45:33')

# %%
pd.Timestamp('2016-01-06T05:34:43.123785') # 컴퓨터가 좋아하는 형식
# Out:
# Timestamp('2016-01-06 05:34:43.123785')

# %%
#정수를 Timestamp에 넘기게 되면, 유닉스 시간에 따라 경과된 나노초에 해당하는 날짜를 알려줍니다.
#그러니까, 1970년 1월 1일 + n 나노초 가 되는 것이죠.

pd.Timestamp(500)
# Out:
# Timestamp('1970-01-01 00:00:00.000000500')

# %%
pd.Timestamp(5001, unit='D') # unit을 표기해줘 day라는 것을 알려줍니다.
# Out:
# Timestamp('1983-09-11 00:00:00')

# %%
#pandas 에서 to_datetime 이란 메서드는 Timestamp 와 하는 일이 매우 유사합니다.
#하지만 조금의 유연성을 더 가지고 있어요.

pd.to_datetime('2015-5-13')
# Out:
# Timestamp('2015-05-13 00:00:00')

# %%
pd.to_datetime('2015-13-5', dayfirst=True)
# Out:
# Timestamp('2015-05-13 00:00:00')

# %%
pd.to_datetime('Start Date: Sep 30, 2017 Start Time: 1:30 pm',
              format='Start Date: %b %d, %Y Start Time: %I:%M %p')
# Out:
# Timestamp('2017-09-30 13:30:00')

# %%
pd.to_datetime(100, unit='D', origin='2013-01-01')
# Out:
# Timestamp('2013-04-11 00:00:00')

# %%
# to_datetime 을 활용하면 시리즈나 df 에서도 쉽게 날짜 형태를 만들 수 있습니다.

s = pd.Series([10, 100, 1000, 10000])
pd.to_datetime(s, unit='D')
# Out:
# 0   1970-01-11
# 1   1970-04-11
# 2   1972-09-27
# 3   1997-05-19
# dtype: datetime64[ns]

# %%
s = pd.Series(['12-5-2015', '14-1-2013', '20/12/2017', '40/23/2017'])#마지막 날짜 주목!
pd.to_datetime(s, dayfirst=True, errors='coerce') #coerce 안 쓰면 애러가 나요
# Out:
# 0     12-5-2015
# 1     14-1-2013
# 2    20/12/2017
# 3    40/23/2017
# dtype: object

# %%
#pandas 에서도 timedelta 관련 함수들이 있습니다.
#역시 pd.Timedelta 와 pd.to_timedelta 가 있고, 후자가 조금 더 유연성을 가집니다.

pd.Timedelta('12 days 5 hours 3 minutes 123545 nanoseconds')
# Out:
# Timedelta('12 days 05:03:00.000123545')

# %%
pd.Timedelta(days=5, minutes=7.42)
# Out:
# Timedelta('5 days 00:07:25.200000')

# %%
pd.Timedelta(100, unit='W') #unit 이 week
# Out:
# Timedelta('700 days 00:00:00')

# %%
pd.to_timedelta('56:15:45.349') # 시:분:초
# Out:
# Timedelta('2 days 08:15:45.349000')

# %%
s = pd.Series([10, 100])
pd.to_timedelta(s, unit='s')
# Out:
# 0   0 days 00:00:10
# 1   0 days 00:01:40
# dtype: timedelta64[ns]

# %%
time_str = ['2 days 24 minutes 89.53 seconds', '00:45:23.6']
pd.to_timedelta(time_str)
# Out:
# TimedeltaIndex(['2 days 00:25:29.530000', '0 days 00:45:23.600000'], dtype='timedelta64[ns]', freq=None)

# %%
#timedelta 끼리는 연산도 가능합니다.

pd.Timedelta('12 days 5 hours 3 minutes')*2
# Out:
# Timedelta('24 days 10:06:00')

# %%
(
    pd.Timestamp('1/1/2017') + 
    pd.Timedelta('12 days 5 hours 3 minutes')*2
)
# Out:
# Timestamp('2017-01-25 10:06:00')

# %%
pd.to_timedelta([10, 100], unit='s') + pd.to_timedelta(['3 hours', '5 hours'])
# Out:
# TimedeltaIndex(['0 days 03:00:10', '0 days 05:01:40'], dtype='timedelta64[ns]', freq=None)

# %%
#심지어는 나눗셈도 가능합니다.

pd.Timedelta('12 days') / pd.Timedelta('3 days')
# Out:
# 4.0

# %%
# timestamp 와 timedelta는 많은 메서드들을 가지고 있습니다.
# 예를 들어..

ts = pd.Timestamp('2016-10-1 4:23:23.4')

ts.ceil('h')
# Out:
# Timestamp('2016-10-01 05:00:00')

# %%
ts.year, ts.month, ts.day, ts.hour, ts.minute, ts.second
# Out:
# (2016, 10, 1, 4, 23, 23)

# %%
ts.dayofweek, ts.dayofyear, ts.daysinmonth
# Out:
# (5, 275, 31)

# %%
ts.to_pydatetime()
# Out:
# datetime.datetime(2016, 10, 1, 4, 23, 23, 400000)

# %%
td = pd.Timedelta(123.456, unit='h')
td
# Out:
# Timedelta('5 days 03:27:21.600000')

# %%
td.round('min')
# Out:
# Timedelta('5 days 03:27:00')

# %%
td.components
# Out:
# Components(days=5, hours=3, minutes=27, seconds=21, milliseconds=600, microseconds=0, nanoseconds=0)

# %%
td.total_seconds()
# Out:
# 444441.6

# %% [markdown]
# # 2. 시계열을 이용한 슬라이스
#
# 날짜를 이용해서 데이터를 나누는 법을 배워봅시다.

# %%
crime = pd.read_hdf('data/crime.h5', 'crime')
crime.dtypes
# Out:
# OFFENSE_TYPE_ID              category
# OFFENSE_CATEGORY_ID          category
# REPORTED_DATE          datetime64[ns]
# GEO_LON                       float64
# GEO_LAT                       float64
# NEIGHBORHOOD_ID              category
# IS_CRIME                        int64
# IS_TRAFFIC                      int64
# dtype: object

# %%
#tables 가 필요하다고 하니 설치합시다.
# !pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.6.1-2-cp38-cp38-win_amd64.whl (3.1 MB)
# Collecting numexpr>=2.6.2
#   Downloading numexpr-2.7.3-cp38-cp38-win_amd64.whl (93 kB)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\kch_dorm\anaconda3\lib\site-packages (from tables) (1.20.2)
# Installing collected packages: numexpr, tables
# Successfully installed numexpr-2.7.3 tables-3.6.1

# %%
crime = pd.read_hdf('data/crime.h5', 'crime')
crime.dtypes
# Out:
# OFFENSE_TYPE_ID              category
# OFFENSE_CATEGORY_ID          category
# REPORTED_DATE          datetime64[ns]
# GEO_LON                       float64
# GEO_LAT                       float64
# NEIGHBORHOOD_ID              category
# IS_CRIME                        int64
# IS_TRAFFIC                      int64
# dtype: object

# %%
#csv와 달리 h5는 데이터의 형태를 기억합니다.
# dtypes 가 다양하게 있고, category 3개, 날짜 1개가 있네요.
# date 를 인덱스로 만든 뒤 여러 가지를 해봅시다.

crime = crime.set_index('REPORTED_DATE')
crime
# Out:
#                                   OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 
EIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2015-03-04 22:25:00 -104.973896  39.769064           five-points         0
# 2015-03-04 22:30:00 -104.906412  39.632816         hampden-south         0
# 2015-03-04 22:32:00 -104.979180  39.706613  washington-park-west         0
# 2015-03-04 22:33:00 -104.991655  39.740067          civic-center         0
# 2015-03-04 22:36:00 -105.045235  39.667928           harvey-park         1
# ...                         ...        ...                   ...       ...
# 2016-01-01 11:10:00 -104.819450  39.791615             montbello         1
# 2016-01-01 11:11:00 -104.981701  39.736814          capitol-hill         0
# 2016-01-01 11:11:00 -104.973731  39.714223                 speer         0
# 2016-01-01 11:16:00 -104.977509  39.783541            globeville         1
# 2016-01-01 11:22:00 -105.053250  39.731282            villa-park         0
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2015-03-04 22:25:00           1
# 2015-03-04 22:30:00           1
# 2015-03-04 22:32:00           1
# 2015-03-04 22:33:00           1
# 2015-03-04 22:36:00           0
# ...                         ...
# 2016-01-01 11:10:00           0
# 2016-01-01 11:11:00           1
# 2016-01-01 11:11:00           1
# 2016-01-01 11:16:00           0
# 2016-01-01 11:22:00           1
#
# [75071 rows x 7 columns]

# %%
#위의 작업이 가능한 이유는 현재 index가 DatetimeIndex이기 때문입니다. 확인해볼까요?
crime.index
# Out:
# DatetimeIndex(['2014-06-29 02:01:00', '2014-06-29 01:54:00',
#                '2014-06-29 02:00:00', '2014-06-29 02:18:00',
#                '2014-06-29 04:17:00', '2014-06-29 04:22:00',
#                '2014-06-29 02:56:00', '2014-06-29 04:54:00',
#                '2014-01-20 08:29:00', '2014-06-29 03:56:00',
#                ...
#                '2017-09-12 13:40:00', '2017-09-12 18:13:00',
#                '2017-09-13 01:12:00', '2017-09-12 15:33:00',
#                '2017-09-12 14:00:00', '2017-09-13 05:48:00',
#                '2017-09-12 20:37:00', '2017-09-12 16:32:00',
#                '2017-09-12 13:04:00', '2017-09-12 09:30:00'],
#               dtype='datetime64[ns]', name='REPORTED_DATE', length=460911, freq=None)

# %% [markdown]
# # 3. 인덱스가 아닌 상태에서 불리언 필터링

# %%
crime = pd.read_hdf('data/crime.h5', 'crime')

(
    crime[crime.REPORTED_DATE == '2016-05-12 16:45:00']
)
# Out:
#              OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 300905      traffic-accident    traffic-accident 2016-05-12 16:45:00
# 302354      traffic-accident    traffic-accident 2016-05-12 16:45:00
# 302373  fraud-identity-theft  white-collar-crime 2016-05-12 16:45:00
#
#            GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 300905 -104.847024  39.779596       montbello         0           1
# 302354 -105.049180  39.769296   west-highland         0           1
# 302373 -104.931971  39.717359         hilltop         1           0

# %%
#이렇게 불러올 때, 날짜를 일부만 넣으면 아무 것도 나오지 않아요.

(
    crime[crime.REPORTED_DATE == '2016-05-12']
)
# Out:
# Empty DataFrame
# Columns: [OFFENSE_TYPE_ID, OFFENSE_CATEGORY_ID, REPORTED_DATE, GEO_LON, GEO_LAT, NEIGHBORHOOD_ID, IS_CRIME, IS_TRAFFIC]
# Index: []

# %%
(crime.REPORTED_DATE == '2016-05-12').sum()
# Out:
# 0

# %%
#between 을 사용해봅시다. # 비트윈은 사이의값 가져옴 

(
    crime[crime.REPORTED_DATE.between('2016-05-12', '2016-05-13')]
)
# Out:
#                 OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 295715  criminal-mischief-other               public-disorder
# 296474        liquor-possession                  drug-alcohol
# 297204         traffic-accident              traffic-accident
# 299383            theft-bicycle                       larceny
# 299389   theft-of-motor-vehicle                    auto-theft
# ...                         ...                           ...
# 358208       public-peace-other               public-disorder
# 358448        threats-to-injure               public-disorder
# 363134            sex-aslt-rape                sexual-assault
# 365959   menacing-felony-w-weap            aggravated-assault
# 378711               assault-dv  other-crimes-against-persons
#
#              REPORTED_DATE     GEO_LON    GEO_LAT      NEIGHBORHOOD_ID  \
# 295715 2016-05-12 23:51:00 -105.017241  39.705845          athmar-park
# 296474 2016-05-12 18:40:00 -104.995692  39.747875                  cbd
# 297204 2016-05-12 22:26:00 -104.880037  39.777037            stapleton
# 299383 2016-05-12 20:35:00 -104.929350  39.763797  northeast-park-hill
# 299389 2016-05-12 09:39:00 -104.941233  39.775510       elyria-swansea
# ...                    ...         ...        ...                  ...
# 358208 2016-05-12 17:55:00 -105.027747  39.700029             westwood
# 358448 2016-05-12 19:24:00 -104.947118  39.763777              clayton
# 363134 2016-05-12 22:28:00         NaN        NaN    harvey-park-south
# 365959 2016-05-12 15:59:00 -104.935172  39.723703              hilltop
# 378711 2016-05-12 16:39:00 -104.974700  39.740555   north-capitol-hill
#
#         IS_CRIME  IS_TRAFFIC
# 295715         1           0
# 296474         1           0
# 297204         0           1
# 299383         1           0
# 299389         1           0
# ...          ...         ...
# 358208         1           0
# 358448         1           0
# 363134         1           0
# 365959         1           0
# 378711         1           0
#
# [243 rows x 8 columns]

# %%
#between 을 쓰면 년/월 기준으로도 자를 수 있습니다.

(
    crime[crime.REPORTED_DATE.between('2016-05', '2016-06')].sort_values('REPORTED_DATE')
)
# Out:
#                     OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 289289                  theft-other                       larceny
# 283336      criminal-mischief-other               public-disorder
# 283335            threats-to-injure               public-disorder
# 289275         disturbing-the-peace               public-disorder
# 165247   vehicular-eluding-no-chase              all-other-crimes
# ...                             ...                           ...
# 316279       traf-habitual-offender              all-other-crimes
# 317825    public-order-crimes-other              all-other-crimes
# 311934  burglary-residence-no-force                      burglary
# 314189                   assault-dv  other-crimes-against-persons
# 309627                  theft-other                       larceny
#
#              REPORTED_DATE     GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# 289289 2016-05-01 00:03:00 -104.948370  39.740322       city-park         1
# 283336 2016-05-01 00:09:00 -104.963126  39.738641   cheesman-park         1
# 283335 2016-05-01 00:09:00 -104.963126  39.738641   cheesman-park         1
# 289275 2016-05-01 00:09:00 -104.963126  39.738641   cheesman-park         1
# 165247 2016-05-01 00:27:00 -105.022877  39.692959       ruby-hill         1
# ...                    ...         ...        ...             ...       ...
# 316279 2016-05-31 23:31:00 -104.903518  39.683885    indian-creek         1
# 317825 2016-05-31 23:31:00 -104.903518  39.683885    indian-creek         1
# 311934 2016-05-31 23:34:00 -104.886163  39.741763     east-colfax         1
# 314189 2016-05-31 23:34:00 -104.886163  39.741763     east-colfax         1
# 309627 2016-05-31 23:53:00 -104.963061  39.740170  city-park-west         1
#
#         IS_TRAFFIC
# 289289           0
# 283336           0
# 283335           0
# 289275           0
# 165247           0
# ...            ...
# 316279           0
# 317825           0
# 311934           0
# 314189           0
# 309627           0
#
# [8012 rows x 8 columns]

# %%
(
    crime[crime.REPORTED_DATE.between('2016', '2017')].sort_values('REPORTED_DATE')
)
# Out:
#                      OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 375076                assault-simple  other-crimes-against-persons
# 283748            aggravated-assault            aggravated-assault
# 272581          disturbing-the-peace               public-disorder
# 286739                    traf-other              all-other-crimes
# 284245  traffic-accident-hit-and-run              traffic-accident
# ...                              ...                           ...
# 346842     traffic-accident-dui-duid              traffic-accident
# 367058                 harassment-dv               public-disorder
# 361186          drug-cocaine-possess                  drug-alcohol
# 359750             liquor-possession                  drug-alcohol
# 353605   drug-methampetamine-possess                  drug-alcohol
#
#              REPORTED_DATE     GEO_LON    GEO_LAT     NEIGHBORHOOD_ID  \
# 375076 2016-01-01 00:17:00 -105.044064  39.696096             mar-lee
# 283748 2016-01-01 00:25:00 -104.993574  39.739773        civic-center
# 272581 2016-01-01 00:30:00 -104.974995  39.767704         five-points
# 286739 2016-01-01 00:33:00 -104.940621  39.751036     south-park-hill
# 284245 2016-01-01 00:37:00 -104.986106  39.747526  north-capitol-hill
# ...                    ...         ...        ...                 ...
# 346842 2016-12-31 23:16:00 -105.025137  39.725426              barnum
# 367058 2016-12-31 23:23:00 -104.978298  39.740637  north-capitol-hill
# 361186 2016-12-31 23:27:00 -104.992172  39.714807               baker
# 359750 2016-12-31 23:51:00 -104.989266  39.752146         five-points
# 353605 2016-12-31 23:58:00 -105.024481  39.714752            valverde
#
#         IS_CRIME  IS_TRAFFIC
# 375076         1           0
# 283748         1           0
# 272581         1           0
# 286739         1           0
# 284245         0           1
# ...          ...         ...
# 346842         0           1
# 367058         1           0
# 361186         1           0
# 359750         1           0
# 353605         1           0
#
# [91076 rows x 8 columns]

# %%
#패턴을 사용한 매칭
(
    crime[crime.REPORTED_DATE.between('2016 Sep, 15', '2016 Sep, 16')]
)
# Out:
#                      OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 331184             liquor-possession                  drug-alcohol
# 331255                    assault-dv  other-crimes-against-persons
# 331427     criminal-mischief-mtr-veh               public-disorder
# 333909              traffic-accident              traffic-accident
# 333922  traffic-accident-hit-and-run              traffic-accident
# ...                              ...                           ...
# 361782    criminal-mischief-graffiti               public-disorder
# 369038                assault-simple  other-crimes-against-persons
# 370257            aggravated-assault            aggravated-assault
# 373453             threats-to-injure               public-disorder
# 373454                    assault-dv  other-crimes-against-persons
#
#              REPORTED_DATE     GEO_LON    GEO_LAT             NEIGHBORHOOD_ID  \
# 331184 2016-09-15 22:40:00 -105.000542  39.739501                lincoln-park
# 331255 2016-09-15 21:25:00 -105.016259  39.757616                    highland
# 331427 2016-09-15 10:30:00 -104.987565  39.700698                       baker
# 333909 2016-09-15 18:21:00 -104.790479  39.774432  gateway-green-valley-ranch
# 333922 2016-09-15 03:12:00 -105.032781  39.686004                     mar-lee
# ...                    ...         ...        ...                         ...
# 361782 2016-09-15 17:40:00 -104.974517  39.757904                 five-points
# 369038 2016-09-15 13:48:00 -104.994520  39.731349                lincoln-park
# 370257 2016-09-15 19:10:00 -105.018500  39.782887                   sunnyside
# 373453 2016-09-15 10:34:00 -104.988854  39.723849                       baker
# 373454 2016-09-15 11:53:00 -105.018437  39.676584   college-view-south-platte
#
#         IS_CRIME  IS_TRAFFIC
# 331184         1           0
# 331255         1           0
# 331427         1           0
# 333909         0           1
# 333922         0           1
# ...          ...         ...
# 361782         1           0
# 369038         1           0
# 370257         1           0
# 373453         1           0
# 373454         1           0
#
# [252 rows x 8 columns]

# %%
#between 을 쓸 때 조심할 점은, 시간포함 여부입니다.
# 어떤 말인지 아래의 예를 볼까요?

#2016-05-13 을 넣었을 땐, 12일까지만 
(
    crime[crime.REPORTED_DATE.between('2016-05-12', '2016-05-15')].sort_values('REPORTED_DATE')
)
# Out:
#                   OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 310555  public-order-crimes-other              all-other-crimes
# 315074                     curfew               public-disorder
# 312836                 traf-other              all-other-crimes
# 310538   police-false-information              all-other-crimes
# 311301     traf-habitual-offender              all-other-crimes
# ...                           ...                           ...
# 314394                     curfew               public-disorder
# 312142       drug-cocaine-possess                  drug-alcohol
# 312897    drug-poss-paraphernalia                  drug-alcohol
# 313643    drug-poss-paraphernalia                  drug-alcohol
# 312259                 assault-dv  other-crimes-against-persons
#
#              REPORTED_DATE     GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# 310555 2016-05-12 00:05:00 -104.987417  39.727275    civic-center         1
# 315074 2016-05-12 00:07:00 -104.987432  39.726668    lincoln-park         1
# 312836 2016-05-12 00:13:00 -105.053191  39.719419     barnum-west         1
# 310538 2016-05-12 00:33:00 -104.965948  39.764498            cole         1
# 311301 2016-05-12 01:01:00 -104.902327  39.771602       stapleton         1
# ...                    ...         ...        ...             ...       ...
# 314394 2016-05-14 23:19:00 -104.987485  39.739897    civic-center         1
# 312142 2016-05-14 23:21:00 -105.025810  39.787361           regis         1
# 312897 2016-05-14 23:22:00 -105.024375  39.686931       ruby-hill         1
# 313643 2016-05-14 23:38:00 -104.988019  39.753420     five-points         1
# 312259 2016-05-15 00:00:00 -105.045394  39.710769        westwood         1
#
#         IS_TRAFFIC
# 310555           0
# 315074           0
# 312836           0
# 310538           0
# 311301           0
# ...            ...
# 314394           0
# 312142           0
# 312897           0
# 313643           0
# 312259           0
#
# [726 rows x 8 columns]

# %%
#시간을 넣으면 해당 시간 전까지만. 그러니까 뒤에 들어오는 시간 전까지 들어가는 것이죠.
(
    crime[crime.REPORTED_DATE.between('2016-05-12', '2016-05-13 23:59:59')].sort_values('REPORTED_DATE')
)
# Out:
#                   OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 310555  public-order-crimes-other              all-other-crimes
# 315074                     curfew               public-disorder
# 312836                 traf-other              all-other-crimes
# 310538   police-false-information              all-other-crimes
# 311301     traf-habitual-offender              all-other-crimes
# ...                           ...                           ...
# 296472             assault-simple  other-crimes-against-persons
# 313611                 assault-dv  other-crimes-against-persons
# 295699     drug-marijuana-possess                  drug-alcohol
# 303817     traf-vehicular-assault              all-other-crimes
# 304581                 traf-other              all-other-crimes
#
#              REPORTED_DATE     GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# 310555 2016-05-12 00:05:00 -104.987417  39.727275    civic-center         1
# 315074 2016-05-12 00:07:00 -104.987432  39.726668    lincoln-park         1
# 312836 2016-05-12 00:13:00 -105.053191  39.719419     barnum-west         1
# 310538 2016-05-12 00:33:00 -104.965948  39.764498            cole         1
# 311301 2016-05-12 01:01:00 -104.902327  39.771602       stapleton         1
# ...                    ...         ...        ...             ...       ...
# 296472 2016-05-13 23:30:00 -105.005423  39.759334        highland         1
# 313611 2016-05-13 23:30:00 -105.005423  39.759334        highland         1
# 295699 2016-05-13 23:33:00 -104.988300  39.741702             cbd         1
# 303817 2016-05-13 23:34:00 -105.025194  39.784383        berkeley         1
# 304581 2016-05-13 23:55:00 -104.809898  39.775047       montbello         1
#
#         IS_TRAFFIC
# 310555           0
# 315074           0
# 312836           0
# 310538           0
# 311301           0
# ...            ...
# 296472           0
# 313611           0
# 295699           0
# 303817           1
# 304581           0
#
# [514 rows x 8 columns]

# %%
#이 외에 DatetimeIndex에서만 가능한 여러 작업들을 확인해봅시다.

crime = pd.read_hdf('data/crime.h5', 'crime').set_index('REPORTED_DATE')

# %%
#날짜에 관계 없이 특정 시간을 선택
crime.between_time('2:00', '5:00', include_end=False)
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00       traffic-accident-dui-duid
# 2014-06-29 02:00:00            disturbing-the-peace
# 2014-06-29 02:18:00                          curfew
# 2014-06-29 04:17:00              aggravated-assault
# 2014-06-29 04:22:00  violation-of-restraining-order
# ...                                             ...
# 2017-08-25 04:41:00        theft-items-from-vehicle
# 2017-09-13 04:17:00          theft-of-motor-vehicle
# 2017-09-13 02:21:00                  assault-simple
# 2017-09-13 03:21:00       traffic-accident-dui-duid
# 2017-09-13 02:15:00    traffic-accident-hit-and-run
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-06-29 02:01:00              traffic-accident -105.000149  39.745753
# 2014-06-29 02:00:00               public-disorder -105.020719  39.706674
# 2014-06-29 02:18:00               public-disorder -105.001552  39.769505
# 2014-06-29 04:17:00            aggravated-assault -105.018557  39.679229
# 2014-06-29 04:22:00              all-other-crimes -104.972447  39.739449
# ...                                           ...         ...        ...
# 2017-08-25 04:41:00      theft-from-motor-vehicle -104.880586  39.645164
# 2017-09-13 04:17:00                    auto-theft -105.028694  39.708288
# 2017-09-13 02:21:00  other-crimes-against-persons -104.925733  39.654184
# 2017-09-13 03:21:00              traffic-accident -105.010711  39.757385
# 2017-09-13 02:15:00              traffic-accident -105.043950  39.787436
#
#                                NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-06-29 02:01:00                        cbd         0           1
# 2014-06-29 02:00:00                athmar-park         1           0
# 2014-06-29 02:18:00                  sunnyside         1           0
# 2014-06-29 04:17:00  college-view-south-platte         1           0
# 2014-06-29 04:22:00              cheesman-park         1           0
# ...                                        ...       ...         ...
# 2017-08-25 04:41:00              hampden-south         1           0
# 2017-09-13 04:17:00                   westwood         1           0
# 2017-09-13 02:21:00           university-hills         1           0
# 2017-09-13 03:21:00                   highland         0           1
# 2017-09-13 02:15:00                      regis         0           1
#
# [29078 rows x 7 columns]

# %%
#모든 날짜에 대해 특정 시각 선택
crime.at_time('5:47')
# Out:
#                                   OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2013-11-26 05:47:00       criminal-mischief-other           public-disorder
# 2017-04-09 05:47:00     criminal-mischief-mtr-veh           public-disorder
# 2017-02-19 05:47:00       criminal-mischief-other           public-disorder
# 2017-02-16 05:47:00            aggravated-assault        aggravated-assault
# 2017-02-12 05:47:00           police-interference          all-other-crimes
# ...                                           ...                       ...
# 2013-09-10 05:47:00              traffic-accident          traffic-accident
# 2013-03-14 05:47:00                   theft-other                   larceny
# 2012-10-08 05:47:00      theft-items-from-vehicle  theft-from-motor-vehicle
# 2013-08-21 05:47:00      theft-items-from-vehicle  theft-from-motor-vehicle
# 2017-08-23 05:47:00  traffic-accident-hit-and-run          traffic-accident
#
#                         GEO_LON    GEO_LAT           NEIGHBORHOOD_ID  \
# REPORTED_DATE
# 2013-11-26 05:47:00 -104.991476  39.751536                       cbd
# 2017-04-09 05:47:00 -104.959394  39.678425                university
# 2017-02-19 05:47:00 -104.986767  39.741336        north-capitol-hill
# 2017-02-16 05:47:00 -104.934029  39.732320                      hale
# 2017-02-12 05:47:00 -104.976306  39.722644                     speer
# ...                         ...        ...                       ...
# 2013-09-10 05:47:00 -104.986311  39.708426      washington-park-west
# 2013-03-14 05:47:00 -105.047861  39.727237                villa-park
# 2012-10-08 05:47:00 -105.037308  39.768336             west-highland
# 2013-08-21 05:47:00 -105.021310  39.758076            jefferson-park
# 2017-08-23 05:47:00 -104.931056  39.702503  washington-virginia-vale
#
#                      IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2013-11-26 05:47:00         1           0
# 2017-04-09 05:47:00         1           0
# 2017-02-19 05:47:00         1           0
# 2017-02-16 05:47:00         1           0
# 2017-02-12 05:47:00         1           0
# ...                       ...         ...
# 2013-09-10 05:47:00         0           1
# 2013-03-14 05:47:00         1           0
# 2012-10-08 05:47:00         1           0
# 2013-08-21 05:47:00         1           0
# 2017-08-23 05:47:00         0           1
#
# [118 rows x 7 columns]

# %%
#데이터의 첫 6개월 선택
crime_sort = crime.sort_index()
crime_sort.first(pd.offsets.MonthBegin(6))
#그런데 7월이 껴있네요?
# Out:
#                                     OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault  aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order    all-other-crimes
# 2012-01-02 00:16:00       traffic-accident-dui-duid    traffic-accident
# 2012-01-02 00:47:00                traffic-accident    traffic-accident
# 2012-01-02 01:35:00              aggravated-assault  aggravated-assault
# ...                                             ...                 ...
# 2012-06-30 23:40:00       traffic-accident-dui-duid    traffic-accident
# 2012-06-30 23:44:00                traffic-accident    traffic-accident
# 2012-06-30 23:50:00       criminal-mischief-mtr-veh     public-disorder
# 2012-06-30 23:54:00    traffic-accident-hit-and-run    traffic-accident
# 2012-07-01 00:01:00                  robbery-street             robbery
#
#                         GEO_LON    GEO_LAT      NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2012-01-02 00:06:00 -104.816860  39.796717            montbello         1
# 2012-01-02 00:06:00 -104.816860  39.796717            montbello         1
# 2012-01-02 00:16:00 -104.971851  39.736874        cheesman-park         0
# 2012-01-02 00:47:00 -104.951824  39.740168        congress-park         0
# 2012-01-02 01:35:00 -104.998131  39.749922        union-station         1
# ...                         ...        ...                  ...       ...
# 2012-06-30 23:40:00 -104.922266  39.678471            goldsmith         0
# 2012-06-30 23:44:00 -104.987578  39.711158                baker         0
# 2012-06-30 23:50:00 -104.838271  39.788683            montbello         1
# 2012-06-30 23:54:00 -105.014162  39.740439         lincoln-park         0
# 2012-07-01 00:01:00 -104.924292  39.767585  northeast-park-hill         1
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00           0
# 2012-01-02 00:06:00           0
# 2012-01-02 00:16:00           1
# 2012-01-02 00:47:00           1
# 2012-01-02 01:35:00           0
# ...                         ...
# 2012-06-30 23:40:00           1
# 2012-06-30 23:44:00           1
# 2012-06-30 23:50:00           0
# 2012-06-30 23:54:00           1
# 2012-07-01 00:01:00           0
#
# [27489 rows x 7 columns]

# %%
# 또 다른 offset. 그런데 이번에는 6/30 04:00 까지만 나오네요?
crime_sort.first(pd.offsets.MonthEnd(6))
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# ...                                             ...
# 2012-06-29 23:01:00              aggravated-assault
# 2012-06-29 23:11:00                traffic-accident
# 2012-06-29 23:41:00                  robbery-street
# 2012-06-29 23:57:00                  assault-simple
# 2012-06-30 00:04:00                traffic-accident
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2012-01-02 00:06:00            aggravated-assault -104.816860  39.796717
# 2012-01-02 00:06:00              all-other-crimes -104.816860  39.796717
# 2012-01-02 00:16:00              traffic-accident -104.971851  39.736874
# 2012-01-02 00:47:00              traffic-accident -104.951824  39.740168
# 2012-01-02 01:35:00            aggravated-assault -104.998131  39.749922
# ...                                           ...         ...        ...
# 2012-06-29 23:01:00            aggravated-assault -105.019673  39.733250
# 2012-06-29 23:11:00              traffic-accident -104.918451  39.653080
# 2012-06-29 23:41:00                       robbery -104.991912  39.756163
# 2012-06-29 23:57:00  other-crimes-against-persons -104.987360  39.715162
# 2012-06-30 00:04:00              traffic-accident -104.894697  39.628902
#
#                     NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00       montbello         1           0
# 2012-01-02 00:06:00       montbello         1           0
# 2012-01-02 00:16:00   cheesman-park         0           1
# 2012-01-02 00:47:00   congress-park         0           1
# 2012-01-02 01:35:00   union-station         1           0
# ...                             ...       ...         ...
# 2012-06-29 23:01:00      sun-valley         1           0
# 2012-06-29 23:11:00  southmoor-park         0           1
# 2012-06-29 23:41:00     five-points         1           0
# 2012-06-29 23:57:00           speer         1           0
# 2012-06-30 00:04:00   hampden-south         0           1
#
# [27332 rows x 7 columns]

# %%
#normalize를 추가하면, 시간 구성요소를 0으로 만들어서 정확하게 6개월을 잡습니다.
#이 부분은 나중에 여러분이 시계열을 다루게되면 찾아서 써보세요!
crime_sort.first(pd.offsets.MonthBegin(6, normalize=True))
# Out:
#                                     OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-ass
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00           0
# 2012-01-02 00:06:00           0
# 2012-01-02 00:16:00           1
# 2012-01-02 00:47:00           1
# 2012-01-02 01:35:00           0
# ...                         ...
# 2012-06-30 23:40:00           1
# 2012-06-30 23:40:00           1
# 2012-06-30 23:44:00           1
# 2012-06-30 23:50:00           0
# 2012-06-30 23:54:00           1
#
# [27488 rows x 7 columns]

# %%
#pandas 에는 다양한 offset 들이 존재하고, 이를 잘 활용하면 편리하게 이용할 수 있습니다.

crime_sort.first('5D')
# Out:
#                                     OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order
# 2012-01-02 00:16:00       traffic-accident-dui-duid
# 2012-01-02 00:47:00                traffic-accident
# 2012-01-02 01:35:00              aggravated-assault
# ...                                             ...
# 2012-01-06 23:11:00        theft-items-from-vehicle
# 2012-01-06 23:23:00  violation-of-restraining-order
# 2012-01-06 23:30:00                      assault-dv
# 2012-01-06 23:44:00          theft-of-motor-vehicle
# 2012-01-06 23:55:00               threats-to-injure
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2012-01-02 00:06:00            aggravated-assault -104.816860  39.796717
# 2012-01-02 00:06:00              all-other-crimes -104.816860  39.796717
# 2012-01-02 00:16:00              traffic-accident -104.971851  39.736874
# 2012-01-02 00:47:00              traffic-accident -104.951824  39.740168
# 2012-01-02 01:35:00            aggravated-assault -104.998131  39.749922
# ...                                           ...         ...        ...
# 2012-01-06 23:11:00      theft-from-motor-vehicle -104.999752  39.726081
# 2012-01-06 23:23:00              all-other-crimes -104.969588  39.681135
# 2012-01-06 23:30:00  other-crimes-against-persons -104.958983  39.674135
# 2012-01-06 23:44:00                    auto-theft -104.845356  39.794035
# 2012-01-06 23:55:00               public-disorder -105.004788  39.708714
#
#                      NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00        montbello         1           0
# 2012-01-02 00:06:00        montbello         1           0
# 2012-01-02 00:16:00    cheesman-park         0           1
# 2012-01-02 00:47:00    congress-park         0           1
# 2012-01-02 01:35:00    union-station         1           0
# ...                              ...       ...         ...
# 2012-01-06 23:11:00     lincoln-park         1           0
# 2012-01-06 23:23:00       university         1           0
# 2012-01-06 23:30:00  university-park         1           0
# 2012-01-06 23:44:00        montbello         1           0
# 2012-01-06 23:55:00      athmar-park         1           0
#
# [605 rows x 7 columns]

# %%
crime_sort.first('5B') #영업일 기준 5일
# Out:
#                                     OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault        aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order          all-other-crimes
# 2012-01-02 00:16:00       traffic-accident-dui-duid          traffic-accident
# 2012-01-02 00:47:00                traffic-accident          traffic-accident
# 2012-01-02 01:35:00              aggravated-assault        aggravated-assault
# ...                                             ...                       ...
# 2012-01-08 23:46:00        theft-items-from-vehicle  theft-from-motor-vehicle
# 2012-01-08 23:51:00     burglary-residence-no-force                  burglary
# 2012-01-08 23:52:00                     theft-other                   larceny
# 2012-01-09 00:04:00    traffic-accident-hit-and-run          traffic-accident
# 2012-01-09 00:05:00    fraud-criminal-impersonation        white-collar-crime
#
#                         GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 
EIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00                  montbello         1           0
# 2012-01-02 00:06:00                  montbello         1           0
# 2012-01-02 00:16:00              cheesman-park         0           1
# 2012-01-02 00:47:00              congress-park         0           1
# 2012-01-02 01:35:00              union-station         1           0
# ...                                        ...       ...         ...
# 2012-12-30 23:13:00               capitol-hill         0           1
# 2012-12-30 23:14:00            washington-park         1           0
# 2012-12-30 23:39:00                  sunnyside         1           0
# 2012-12-30 23:41:00  college-view-south-platte         0           1
# 2012-12-31 00:05:00               capitol-hill         1           0
#
# [56897 rows x 7 columns]

# %%
#원하는 offset 이 없으면 만들 수 있습니다.
do = pd.DateOffset(years=2, months=5, days=3, hours=8, seconds=10)
pd.Timestamp('2021-1-30') + do
# Out:
# Timestamp('2023-07-03 08:00:10')

# %% [markdown]
# # 4. 주간 범죄 수 계산
#
# 자 이제, 본격적으로 분석에 Timestamp를 이용해봅시다.

# %%
crime_sort = pd.read_hdf('data/crime.h5', 'crime').set_index('REPORTED_DATE').sort_index()

# %%
#resample 은 time series 를 groupby 하는 역할을 합니다.
#예를 들어 주별 범죄수를 구할 땐 다음과 같이 합니다.
#주의 마지막 날은 일요일이고, 이 날짜로 각 인덱스가 설정됩니다.

(
    crime_sort.resample('W').size()
)
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
#               ...
# 2017-09-03    1956
# 2017-09-10    1733
# 2017-09-17    1976
# 2017-09-24    1839
# 2017-10-01    1059
# Freq: W-SUN, Length: 300, dtype: int64

# %%
# 첫 주의 범죄를 확인해봅시다.
len(crime_sort.loc[:'2012-1-8'])
# Out:
# 877

# %%
#주의 마지막 요일을 바꿀 수 있습니다.
(
    crime_sort.resample('W-THU').size()
)
# Out:
# REPORTED_DATE
# 2012-01-05     462
# 2012-01-12    1116
# 2012-01-19     924
# 2012-01-26    1061
# 2012-02-02     926
#               ...
# 2017-09-07    1803
# 2017-09-14    1866
# 2017-09-21    1926
# 2017-09-28    1720
# 2017-10-05      28
# Freq: W-THU, Length: 301, dtype: int64

# %%
#groupby 로 동일한 작업을 할 수 있습니다 (조금 더 복잡하게)
weekly_crimes = (
    crime_sort.groupby(pd.Grouper(freq='W')).size()
)
weekly_crimes
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
#               ...
# 2017-09-03    1956
# 2017-09-10    1733
# 2017-09-17    1976
# 2017-09-24    1839
# 2017-10-01    1059
# Freq: W-SUN, Length: 300, dtype: int64

# %%
#만약  index가 아닌 열에 대해 resample 을 진행하고자 한다면, on 을 씁니다.
crime = pd.read_hdf('data/crime.h5', 'crime')
weekly_crimes2 = crime.resample('W', on='REPORTED_DATE').size()
weekly_crimes2.equals(weekly_crimes)
# Out:
# True

# %%
weekly_crimes_gby2 = crime.groupby(pd.Grouper(key='REPORTED_DATE', freq='W')).size()
weekly_crimes_gby2
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
#               ...
# 2017-09-03    1956
# 2017-09-10    1733
# 2017-09-17    1976
# 2017-09-24    1839
# 2017-10-01    1059
# Freq: W-SUN, Length: 300, dtype: int64

# %%
#간단히 그림을 그려봅시다.
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 4))
weekly_crimes.plot(title='All Denver Crime', ax=ax)
# Out:
# <AxesSubplot:title={'center':'All Denver Crime'}, xlabel='REPORTED_DATE'>

# %%
#crime 데이터는 교통사고와 범죄로 구분됩니다. 이를 나눠서 집계해보죠.

crime = (
    pd.read_hdf('data/crime.h5', 'crime')
    .set_index('REPORTED_DATE')
    .sort_index()
)

# %%
(
    crime
    .resample('Q')
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
)
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31         7882        4726
# 2012-06-30         9641        5255
# 2012-09-30        10566        5003
# 2012-12-31         9197        4802
# 2013-03-31         8730        4442
# 2013-06-30        12259        4510
# 2013-09-30        15799        4942
# 2013-12-31        13910        4968
# 2014-03-31        14487        5021
# 2014-06-30        15833        5225
# 2014-09-30        17342        5734
# 2014-12-31        15028        5783
# 2015-03-31        14989        5380
# 2015-06-30        16924        5825
# 2015-09-30        17891        5988
# 2015-12-31        16090        6117
# 2016-03-31        16423        5590
# 2016-06-30        17547        5861
# 2016-09-30        17427        6199
# 2016-12-31        15984        6094
# 2017-03-31        16426        5587
# 2017-06-30        17486        6148
# 2017-09-30        17990        6101

# %%
(
    crime
    .resample('QS') #QS는 분기의 시작일입니다. 날짜변화를 보세요
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
)
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-01-01         7882        4726
# 2012-04-01         9641        5255
# 2012-07-01        10566        5003
# 2012-10-01         9197        4802
# 2013-01-01         8730        4442
# 2013-04-01        12259        4510
# 2013-07-01        15799        4942
# 2013-10-01        13910        4968
# 2014-01-01        14487        5021
# 2014-04-01        15833        5225
# 2014-07-01        17342        5734
# 2014-10-01        15028        5783
# 2015-01-01        14989        5380
# 2015-04-01        16924        5825
# 2015-07-01        17891        5988
# 2015-10-01        16090        6117
# 2016-01-01        16423        5590
# 2016-04-01        17547        5861
# 2016-07-01        17427        6199
# 2016-10-01        15984        6094
# 2017-01-01        16426        5587
# 2017-04-01        17486        6148
# 2017-07-01        17990        6101

# %%
#이를 시각화해봅시다.
fig, ax = plt.subplots(figsize=(16, 4))
(
    crime
    .resample('Q') #QS는 분기의 시작일입니다. 날짜변화를 보세요
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    .plot(color=['black', 'blue'], ax=ax, title='Denver Crimes and Traffic Accidents')
)
# Out:
# <AxesSubplot:title={'center':'Denver Crimes and Traffic Accidents'}, xlabel='REPORTED_DATE'>

# %%
(
    crime
    .resample('Q')
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    #.iloc[0]
)
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31         7882        4726
# 2012-06-30         9641        5255
# 2012-09-30        10566        5003
# 2012-12-31         9197        4802
# 2013-03-31         8730        4442
# 2013-06-30        12259        4510
# 2013-09-30        15799        4942
# 2013-12-31        13910        4968
# 2014-03-31        14487        5021
# 2014-06-30        15833        5225
# 2014-09-30        17342        5734
# 2014-12-31        15028        5783
# 2015-03-31        14989        5380
# 2015-06-30        16924        5825
# 2015-09-30        17891        5988
# 2015-12-31        16090        6117
# 2016-03-31        16423        5590
# 2016-06-30        17547        5861
# 2016-09-30        17427        6199
# 2016-12-31        15984        6094
# 2017-03-31        16426        5587
# 2017-06-30        17486        6148
# 2017-09-30        17990        6101

# %%
#첫 주를 기준으로 증감비율을 나타내봅시다.

crime_begin = (
    crime
    .resample('Q')
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    .iloc[0]
)

fig, ax = plt.subplots(figsize=(16, 4))
(
    crime
    .resample('Q')
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    .div(crime_begin)
    .sub(1)
    .round(2)
    .plot.bar(color=['black', 'blue'], ax=ax)
)
# Out:
# <AxesSubplot:xlabel='REPORTED_DATE'>

# %% [markdown]
# # 5. dt 속성들
#
# 모든 Timestamp들은 dt 속성을 갖고 있으며 이는 매우 유용합니다.
# 어떤 속성이 있는지는 아래의 예를 통해 알아봅시다.

# %%
crime = pd.read_hdf('data/crime.h5', 'crime')
(
    crime['REPORTED_DATE']
    .dt.day_name()
    .value_counts()
)
# Out:
# Monday       70024
# Friday       69621
# Wednesday    69538
# Thursday     69287
# Tuesday      68394
# Saturday     58834
# Sunday       55213
# Name: REPORTED_DATE, dtype: int64

# %%
#위의 결과를 그래프로 그려봅시다.

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

fig, ax = plt.subplots(figsize=(6, 4))
(
    crime['REPORTED_DATE']
    .dt.day_name()
    .value_counts()
    .reindex(days)
    .plot.barh(ax=ax)
)
# Out:
# <AxesSubplot:>

# %%
#연도별 그래프도 비슷하게 할 수 있죠

fig, ax = plt.subplots(figsize=(6, 4))
(
    crime['REPORTED_DATE']
    .dt.year #이 부분!
    .value_counts()
    .sort_index()
    .plot.barh(ax=ax)
)
# Out:
# <AxesSubplot:>

# %%
# 만약 년도와 요일을 모두 활용하고 싶을 땐 groupby 를 할 수 있습니다.

(
    crime
    .groupby([crime['REPORTED_DATE'].dt.year.rename('year'),
             crime['REPORTED_DATE'].dt.day_name().rename('day')])
    .size()
    .unstack()
)
# Out:
# day   Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# year
# 2012    8549    8786      7442    7189      8440     8191       8440
# 2013   10380   10627      8875    8444     10431    10416      10354
# 2014   12683   12813     10950   10278     12309    12440      12948
# 2015   13273   13452     11586   10624     13512    13381      13320
# 2016   14059   13708     11467   10554     14050    13338      13900
# 2017   10677   10638      8514    8124     10545    10628      10576

# %%
#그런데 2017년의 경우 모든 날이 들어있지 않습니다.
crime.REPORTED_DATE.max()
# Out:
# Timestamp('2017-09-29 06:16:00')

# %%
#다른 해엔 9/29 전에 얼만큼의 범죄가 일어났는지 확인해봅시다.
# 그 비율을 2017년에 곱하기 위해서 말이죠.

crime_pct = (
    crime['REPORTED_DATE']
    .dt.dayofyear.le(272)
    .groupby(crime.REPORTED_DATE.dt.year)
    .mean()
    .mul(100)
    .round(2)
)

# %%
crime_pct
# Out:
# REPORTED_DATE
# 2012     74.84
# 2013     72.54
# 2014     75.06
# 2015     74.81
# 2016     75.15
# 2017    100.00
# Name: REPORTED_DATE, dtype: float64

# %%
crime_pct.loc[2012:2016].median()
# Out:
# 74.84

# %%
def update_2017(df_):
    df_.loc[2017] = (df_
                    .loc[2017]
                     .div(.748)
                     .astype('int')
                    )
    return df_

(
    crime
    .groupby([crime['REPORTED_DATE'].dt.year.rename('year'),
             crime['REPORTED_DATE'].dt.day_name().rename('day')])
    .size()
    .unstack('day')
    .pipe(update_2017)
    .reindex(columns=days)
)
# Out:
# day   Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# year
# 2012    8786     8191       8440      8440    8549      7442    7189
# 2013   10627    10416      10354     10431   10380      8875    8444
# 2014   12813    12440      12948     12309   12683     10950   10278
# 2015   13452    13381      13320     13512   13273     11586   10624
# 2016   13708    13338      13900     14050   14059     11467   10554
# 2017   14221    14208      14139     14097   14274     11382   10860

# %%
#시각화해봅시다.
import seaborn as sns
fig, ax = plt.subplots(figsize=(6, 4))
table = (
    crime
    .groupby([crime['REPORTED_DATE'].dt.year.rename('year'),
             crime['REPORTED_DATE'].dt.day_name().rename('day')])
    .size()
    .unstack('day')
    .pipe(update_2017)
    .reindex(columns=days)
)
sns.heatmap(table, cmap='Greys', ax=ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='year'>

# %%
#범죄가 증가하는 것처럼 보이지만, 인구 변동을 반영하지 않았습니다.
#인구를 확인해봅시다.
denver_pop = pd.read_csv('data/denver_pop.csv', index_col='Year')
denver_pop
# Out:
#       Population
# Year
# 2017      705000
# 2016      693000
# 2015      680000
# 2014      662000
# 2013      647000
# 2012      634000

# %%
den_100k = denver_pop.div(100_000).squeeze() #시리즈를 만든다. 
den_100k
# Out:
# Year
# 2017    7.05
# 2016    6.93
# 2015    6.80
# 2014    6.62
# 2013    6.47
# 2012    6.34
# Name: Population, dtype: float64

# %%
den_100k = denver_pop.div(100_000).squeeze() #시리즈로 변환
fig, ax = plt.subplots(figsize=(6, 4))
table = (
    crime
    .groupby([crime['REPORTED_DATE'].dt.year.rename('year'),
             crime['REPORTED_DATE'].dt.day_name().rename('day')])
    .size()
    .unstack('day')
    .pipe(update_2017)
    .reindex(columns=days)
    .div(den_100k, axis=0)
    .astype(int)
)
sns.heatmap(table, cmap='Greys', ax=ax)
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# # 7. lambda 함수를 이용한 그룹화
#
# 조금 더 복잡한 그룹화를 수행해봅시다.

# %%
crime = (pd.read_hdf('data/crime.h5', 'crime')
        .set_index("REPORTED_DATE")
        .sort_index())

#groupby 에는 lambda 함수를 비롯한 다양한 함수를 넘길 수 있습니다.

(
    crime.groupby(lambda idx: idx.day_name())
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
)
# Out:
#            IS_CRIME  IS_TRAFFIC
# Friday        48833       20814
# Monday        52158       17895
# Saturday      43363       15516
# Sunday        42315       12968
# Thursday      49470       19845
# Tuesday       49658       18755
# Wednesday     50054       19508

# %%
#조금 복잡하게는 다음과 같이 할 수도 있지요.

func = [lambda idx: idx.round('2h').hour, lambda idx:idx.year]

(
    crime.groupby(func)
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    .unstack()
    .style.highlight_max(color='lightgrey')
)
# Out:
# <style  type="text/css" >
# #T_b5eb0_row6_col0,#T_b5eb0_row8_col1,#T_b5eb0_row8_col2,#T_b5eb0_row8_col3,#T_b5eb0_row8_col4,#T_b5eb0_row8_col5,#T_b5eb0_row8_col11,#T_b5eb0_row9_col6,#T_b5eb0_row9_col7,#T_b5eb0_row9_col8,#T_b5eb0_row9_col9,#T_b5eb0_row9_col10{
#             background-color:  lightgrey;
#         }</style><table id="T_b5eb0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan
td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb0_level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_b5eb0_row3_col0" class="data row3 col0" >1067</td>
#                         <td id="T_b5eb0_row3_col1" class="data row3 col1" >1365</td>
#                         <td id="T_b5eb0_row3_col2" class="data row3 col2" >1750</td>
#                         <td id="T_b5eb0_row3_col3" class="data row3 col3" >2167</td>
#                         <td id="T_b5eb0_row3_col4" class="data row3 col4" >2108</td>
#                         <td id="T_b5eb0_row3_col5" class="data row3 col5" >1567</td>
#                         <td id="T_b5eb0_row3_col6" class="data row3 col6" >411</td>
#                         <td id="T_b5eb0_row3_col7" class="data row3 col7" >399</td>
#                         <td id="T_b5eb0_row3_col8" class="data row3 col8" >479</td>
#                         <td id="T_b5eb0_row3_col9" class="data row3 col9" >494</td>
#                         <td id="T_b5eb0_row3_col10" class="data row3 col10" >593</td>
#                         <td id="T_b5eb0_row3_col11" class="data row3 col11" >462</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb0_level0_row4" class="row_heading level0 row4" >8</th>
#                         <td id="T_b5eb0_row4_col0" class="data row4 col0" >2998</td>
#                         <td id="T_b5eb0_row4_col1" class="data row4 col1" >3445</td>
#                         <td id="T_b5eb0_row4_col2" class="data row4 col2" >3727</td>
#                         <td id="T_b5eb0_row4_col3" class="data row4 col3" >4161</td>
#                         <td id="T_b5eb0_row4_col4" class="data row4 col4" >4488</td>
#                         <td id="T_b5eb0_row4_col5" class="data row4 col5" >3251</td>
#                         <td id="T_b5eb0_row4_col6" class="data row4 col6" >1957</td>
#                         <td id="T_b5eb0_row4_col7" class="data row4 col7" >1955</td>
#                         <td id="T_b5eb0_row4_col8" class="data row4 col8" >2210</td>
#                         <td id="T_b5eb0_row4_col9" class="data row4 col9" >2331</td>
#                         <td id="T_b5eb0_row4_col10" class="data row4 col10" >2372</td>
#                         <td id="T_b5eb0_row4_col11" class="data row4 col11" >1828</td>
#             </tr>
#             <tr>
#                         <th id="T_b5eb0_level0_row5" class="row_heading level0 row5" >10</th>
#                         <td id="T_b5eb0_row5_col0" class="data row5 col0" >4305</td>
#                         <td id="T_b5eb0_row5_col1" class="data row5 col1" >5035</td>
#                         <td id="T_b5eb0_row5_col2" class="data row5 col2" >5658</td>
#                         <td id="T_b5eb0_row5_col3" class="data row5 col3" >6205</td>
#                         <td id="T_b5eb0_row5_col4" class="data row5 col4" >6218</td>
#                         <td id="T_b5eb0_row5_col5" class="data row5 col5" >4993</td>
#                         <td id="T_b5eb0_row5_col6" class="data row5 col6" >1979</td>
#                         <td id="T_b5eb0_row5_col7" class="data row5 col7" >1901</td>
#                         <td id="T_b5eb0_row5_col8" class="data row5 col8" >2139</td>
#                         <td id="T_b5eb0_row5_col9" class="data row5 col9" >2320</td>
#                         <td id="T_b

# %%
func = [lambda idx: idx.round('2h').hour, lambda idx:idx.year]

table = (
    crime.groupby(func)
    [['IS_CRIME', 'IS_TRAFFIC']]
    .sum()
    .unstack()
    #.style.highlight_max(color='lightgrey')
)

sns.heatmap(table, cmap='Greys')
# Out:
# <AxesSubplot:xlabel='None-None'>
