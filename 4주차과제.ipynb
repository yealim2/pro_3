# %%
import pandas as pd
import numpy as np

# %%
#movie data
movie = pd.read_csv('data/movie.csv')

# %%
#1. movie 크기 줄이기 

movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movie1= movie.iloc[:,:28].fillna(0)

# %%
movie1.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
original_mem = movie1.memory_usage(deep=True)
original_mem
# Out:
# Index                           128
# color                        306262
# director_name                343388
# num_critic_for_reviews        39328
# duration                      39328
# director_facebook_likes       39328
# actor_3_facebook_likes        39328
# actor_2_name                 346635
# actor_1_facebook_likes        39328
# gross                         39328
# genres                       379929
# actor_1_name                 346599
# movie_title                  356102
# num_voted_users               39328
# cast_total_facebook_likes     39328
# actor_3_name                 346560
# facenumber_in_poster          39328
# plot_keywords                526262
# movie_imdb_link              535844
# num_user_for_reviews          39328
# language                     314142
# country                      297224
# content_rating               285670
# budget                        39328
# title_year                    39328
# actor_2_facebook_likes        39328
# ...

# %%
movie1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   color   4916 non-null   object
# dtypes: object(1)
# memory usage: 38.5+ KB

# %%
movie = pd.read_csv('data/movie.csv')
cols = [
    'RELAFFIL',
    'SATMTMID',
    'CURROPER',
    'INSTNM',
    'STABBR'
]

col2 = movie.loc[:,cols]
col2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7748/3716588883.py in <module>
#       8 ]
#       9
# ---> 10 col2 = movie.loc[:,cols]
#      11 col2.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
#2. college 에서 UGDS 의 최대값을 도시별로 구하기 
college.head()
#INSTNM, CITY, UGDS
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
college = pd.read_csv('data/college.csv')
college1 = college[['CITY','UGDS']]
college1.head()
# Out:
#          CITY     UGDS
# 0      Normal   4206.0
# 1  Birmingham  11383.0
# 2  Montgomery    291.0
# 3  Huntsville   5451.0
# 4  Montgomery   4811.0

# %%
college1.nlargest(27,'UGDS').head()
# Out:
#                CITY      UGDS
# 7116          Tempe  151558.0
# 1189   Indianapolis   77657.0
# 793           Miami   61470.0
# 3711  The Woodlands   59920.0
# 3669        Houston   58084.0

# %%
#3.주별, RELAFFIL 별 UGDS 의 최대값을 구하라 
# INSTNM, STABBR, RELAFFIL, UGDS

# %%
(
    college[['INSTNM','RELAFFIL','UGDS']]
    .sort_values('RELAFFIL', ascending=False)
)
# Out:
#                                                 INSTNM  RELAFFIL     UGDS
# 7534           Excel Learning Center-San Antonio South         1      NaN
# 6609           John Paul the Great Catholic University         1    195.0
# 3674                           Howard Payne University         1   1037.0
# 1145                  Saint Anthony College of Nursing         1    232.0
# 3675                       Huston-Tillotson University         1    972.0
# ...                                                ...       ...      ...
# 2779  Josef's School of Hair Design Inc-Fargo Downtown         0     49.0
# 2777           Headquarters Academy of Hair Design Inc         0     51.0
# 2776     Josef's School of Hair Design Inc-Grand Forks         0     51.0
# 2775                     Nueta Hidatsa Sahnish College         0    137.0
# 3767                 The University of Texas at Austin         0  38914.0
#
# [7535 rows x 3 columns]

# %%
college.UGDS.isna().sum()
# Out:
# 661
